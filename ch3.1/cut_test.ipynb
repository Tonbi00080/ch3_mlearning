# %%
import matplotlib.pyplot as plt
import cv2

# 画像を読みこむ
img = cv2.imread("test.png")
# 画像の切り取り　
# 配列[y1:y2, x1:x2]
im2 = img[50:500, 20:300]

cv2.imwrite("cut-test.png", im2)

# 画像を表示
# cv2.cvtColor(画像ファイル変数,色空間の変換)
# bgr->rgb
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.show()
